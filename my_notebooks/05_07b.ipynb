# %% [markdown]
# ## Multivariate analysis for outlier detection

# %%
import pandas as pd

import matplotlib.pyplot as plt
from pylab import rcParams
import seaborn as sns

# %%
# %matplotlib inline
rcParams['figure.figsize'] = 5, 4
sns.set_style('whitegrid')

# %% [markdown]
# ### Visually inspecting boxplots

# %%
address = '../data/iris.data.csv'
df= pd.read_csv(filepath_or_buffer=address, header=None, sep=',')

df.columns = ['Sepal Length', 'Sepal Width', 'Petal Length', 'Petal Width', 'Species']
x = df.iloc[:,0:4].values
y = df.iloc[:,4].values
df[:5]
# Out:
#    Sepal Length  Sepal Width  Petal Length  Petal Width Species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
sns.boxplot(x='Species', y='Sepal Length', data=df, hue='Species', palette='hls', legend=False)
# Out:
# <AxesSubplot:xlabel='Species', ylabel='Sepal Length'>

# %% [markdown]
# ### Looking at the scatterplot matrix

# %%
sns.pairplot(df, hue='Species', palette='hls')

# %% [markdown]
# #### Identify a record that may be a potential outlier.

# %%
df.where((df['Sepal Width'] < 2.5) & (df['Petal Width'] < 0.5)).dropna()
# Out:
#     Sepal Length  Sepal Width  Petal Length  Petal Width Species
# 41           4.5          2.3           1.3          0.3  setosa
